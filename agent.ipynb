# %%
import gym
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.dqn import MlpPolicy
from stable_baselines3 import PPO, DQN   
from Snake_multiplayer import Snake_game

env = DummyVecEnv([lambda : Snake_game()])

model = PPO('MlpPolicy', env, verbose=1)
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.7.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 506  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 456          |
# |    iterations           | 2            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 7.459312e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 8.34e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.21e+08     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -5.02e-05    |
# |    value_loss           | 3.96e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 437           |
# |    iterations           | 3             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.4755642e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 2.98e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.35e+09      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -1.93e-05     |
# |    value_loss           | 2.76e+09      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 411           |
# |    iterations           | 4             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 4.0745363e-10 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | -2.86e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.66e+09      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -8.02e-06     |
# |    value_loss           | 7.5e+09       |
# -------------------------------------------
# snake :  0 hit you
# snake :  2 hit you
# snake :  2 hit you
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 54            |
# |    iterations           | 5             |
# |    time_elapsed         | 187           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 5.3085387e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.93e+09      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -3.5e-05      |
# |    value_loss           | 3.7e+09       |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 6         |
# |    time_elapsed         | 325       |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.18     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.23e+10  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -3.16e-06 |
# |    value_loss           | 8.24e+10  |
# ---------------------------------------
# opponent collision
# 1705
# snake :  2 hit you
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 41        |
# |    iterations           | 7         |
# |    time_elapsed         | 342       |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.18     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.1e+10   |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -4.87e-06 |
# |    value_loss           | 6.86e+10  |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 8            |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 2.371089e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.57e+08     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -8.34e-05    |
# |    value_loss           | 2.75e+08     |
# ------------------------------------------
# opponent collision
# 1792
# snake :  0 hit you
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 52           |
# |    iterations           | 9            |
# |    time_elapsed         | 353          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 7.332128e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.5e+07      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000121    |
# |    value_loss           | 1.49e+08     |
# ------------------------------------------
# snake :  2 hit you
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 52            |
# |    iterations           | 10            |
# |    time_elapsed         | 387           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 1.1947122e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.64e+08      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -5.38e-05     |
# |    value_loss           | 3.52e+08      |
# -------------------------------------------

# %%
from stable_baselines3.common.env_checker import check_env 
from stable_baselines3.common.vec_env import DummyVecEnv

from Snake_multiplayer import Snake_game

# env = DummyVecEnv([lambda : Snake_game()])
check_env( Snake_game(),warn=True)
# Out:
# hiii

# %%
from stable_baselines3.common.evaluation import evaluate_policy

evaluate_policy(model, env, n_eval_episodes=5, render=True)
